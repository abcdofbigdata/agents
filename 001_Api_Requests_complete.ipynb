# %% [markdown]
# <a href="https://colab.research.google.com/github/abcdofbigdata/agents/blob/main/001_Api_Requests_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.40.69-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<1.41.0,>=1.40.69 (from boto3)
#   Downloading botocore-1.40.69-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.69->boto3) (1.17.0)
# Downloading boto3-1.40.69-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 3.9 MB/s eta 0:00:00
# Downloading botocore-1.40.69-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 69.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.40.69 botocore-1.40.69 jmespath-1.0.1 s3transfer-0.14.0

# %%
import os
from google.colab import userdata

os.environ["AWS_ACCESS_KEY_ID"] = userdata.get('aws_access_key')
os.environ["AWS_SECRET_ACCESS_KEY"] = userdata.get('aws_secret_access_key')

# %%
import boto3

# %%
client = boto3.client("bedrock-runtime", region_name="us-east-1")
model_id = "us.anthropic.claude-sonnet-4-20250514-v1:0"


def add_user_message(messages, text):
    user_message = {"role": "user", "content": [{"text": text}]}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": [{"text": text}]}
    messages.append(assistant_message)


def chat(messages):
    response = client.converse(modelId=model_id, messages=messages)
    return response["output"]["message"]["content"][0]["text"]

# %%
# Make a starting list of messages
messages = []

# Add in the initial user question of "whats 1+1?"
add_user_message(messages, "Whats 1+1?")

# Pass the list of messages into chat to get an answer
answer = chat(messages)

# Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)

# Add in the user's followup question
add_user_message(messages, "And 3 more added to that?")

# Call chat again with the list of messages to get a final answer
answer = chat(messages)
answer
# Out:
# '2 + 3 = 5'

# %%
messages
# Out:
# [{'role': 'user', 'content': [{'text': 'Whats 1+1?'}]},
#  {'role': 'assistant', 'content': [{'text': '1 + 1 = 2'}]},
#  {'role': 'user', 'content': [{'text': 'And 3 more added to that?'}]}]

# %% [markdown]
# ### Exercise Solution

# %%
# Make an initial list of messages
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
    # Get user input
    user_input = input("> ")
    print(f"> {user_input}")

    # Add user's input to list of messages
    add_user_message(messages, user_input)
    # Send list of messages to the API
    text = chat(messages)
    # Add generated text to list of messages
    add_assistant_message(messages, text)
    # Print the generated text
    print(text)
# Out:
# > what is the capital of Denmark
# The capital of Denmark is Copenhagen.
# > What is the biggest company there
# The biggest company in Denmark is **Novo Nordisk**, a pharmaceutical company that specializes in diabetes care and other chronic diseases. It's one of the world's largest insulin manufacturers and has become Denmark's most valuable company by market capitalization.
#
# Other major Danish companies include:
# - **Maersk** - one of the world's largest shipping and logistics companies
# - **Carlsberg** - the famous brewing company
# - **Ørsted** - a major renewable energy company, particularly in offshore wind
#
# Novo Nordisk has grown significantly in recent years, particularly due to the success of medications like Ozempic and Wegovy for diabetes and weight management.
# > Who is the ceo
# The CEO of Novo Nordisk is **Lars Fruergaard Jørgensen**. He has been serving as CEO since January 2017.
#
# Jørgensen joined Novo Nordisk in 1991 and worked his way up through various positions in the company before becoming CEO. Under his leadership, the company has seen significant growth, particularly with the success of their GLP-1 medications like Ozempic and Wegovy.
# > how many employees des it have
# Novo Nordisk has approximately **63,000-65,000 employees** globally as of 2023-2024. The company has been growing significantly in recent years due to the success of their diabetes and obesity medications, which has led to increased hiring.
#
# The workforce is spread across their operations worldwide, with significant presence in:
# - Denmark (headquarters and major facilities)
# - United States
# - China
# - Other international markets
#
# The exact number can vary slightly depending on the reporting date, as the company continues to expand its operations and workforce to meet growing demand for their products.
